# %%
def file_read(pandas):
        txt = open(pandas)
        print(txt.read())
file_read('pandas.ipynb')
# Out:
# {
#  "cells": [
#   {
#    "cell_type": "code",
#    "execution_count": 3,
#    "id": "1674636f-ea6b-40f6-a006-94c7cf390eb1",
#    "metadata": {},
#    "outputs": [
#     {
#      "name": "stdout",
#      "output_type": "stream",
#      "text": [
#       "['blue' 'yellow' 'pink' 'purple']\n",
#       "0      blue\n",
#       "1    yellow\n",
#       "2      pink\n",
#       "3    purple\n",
#       "dtype: object\n"
#      ]
#     }
#    ],
#    "source": [
#     "import pandas as pd\n",
#     "import numpy as np\n",
#     "array = np.array([\"blue\", \"yellow\", \"pink\", \"purple\"])\n",
#     "print(array)\n",
#     "series1 = pd.Series(array)\n",
#     "print(series1)"
#    ]
#   },
#   {
#    "cell_type": "code",
#    "execution_count": null,
#    "id": "d1b06516-3a64-476c-bea3-554d1dc5b8e9",
#    "metadata": {},
#    "outputs": [],
#    "source": []
#   },
#   {
#    "cell_type": "code",
#    "execution_count": 2,
#    "id": "f2ff0181-0a73-44a4-a51b-2f87d974cb5e",
# ...

# %%
f = open("pandas.ipynb",'r',encoding = 'utf-8')
print(f.readline())
# Out:
# {

# %%
def read_lastnlines(checkpoint8,n):
    with open('checkpoint8.ipynb') as f:
        for line in (f.readlines() [-n:]):
            print(line)
read_lastnlines('checkpoint8.ipynb',3)
# Out:
#  "nbformat": 4,
#
#  "nbformat_minor": 5
#
# }

# %%
def count_words(filepath):
    with open(filepath) as f:
        data = f.read()
    data.replace(",", " ")
    return len(data.split(" "))
print(count_words("pandas.ipynb"))
# Out:
# 2616
